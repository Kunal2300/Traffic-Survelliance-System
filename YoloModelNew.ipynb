# %% [markdown]
# <a href="https://colab.research.google.com/github/salunkhegr1712/Traffic-Survelliance-System/blob/master/YoloModelNew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/salunkhegr1712/Yolov7-self
# Out:
# Cloning into 'Yolov7-self'...
# remote: Enumerating objects: 2317, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 2317 (delta 3), reused 204 (delta 3), pack-reused 2108
# Receiving objects: 100% (2317/2317), 1.59 GiB | 18.37 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# Updating files: 100% (1570/1570), done.

# %%
# %cd Yolov7-self
# Out:
# /content/Yolov7-self

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.9 MB/s eta 0:00:00
# ...

# %%
! pip install -r gpu.txt

# %%
# !python train.py --workers 1 --device 0 --batch-size 20 --epochs 50 --img 640 640 --hyp data/hyp.scratch.custom.yaml --name yolov7-custom --weights yolov7.pt
# Out:
# 2023-04-05 12:02:45.758728: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 12:02:46.857597: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 d239fb6 torch 2.0.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# ...

# %%
# !cp -r runs/train/yolov7-custom/ ../drive/MyDrive/
